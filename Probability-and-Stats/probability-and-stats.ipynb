# %%
import numpy as np
import pylab
import pandas as pd
# %matplotlib inline

# %%
flips = np.random.randint(2, size=1000)
# pick randomly between 0 and 1 (exclude 2)

# %%
pylab.hist(flips)
pylab.show()

# %%
pylab.mean(flips)
# Out:
# 0.516

# %%
pylab.median(flips)
# Out:
# 1.0

# %%
pylab.std(flips, ddof=1)
# Out:
# 0.4999939939579214

# %%
p = 0.6
biased_flips = np.random.choice(a=[0, 1], p=[1 - p, p], size=1000)

# %%
pylab.hist(biased_flips)
pylab.show()

# %%
import seaborn as sns
sns.set()

# %%
sns.histplot(biased_flips)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
sns.histplot(biased_flips, stat='probability')
# Out:
# <AxesSubplot:ylabel='Probability'>

# %%
np.mean(biased_flips)
# Out:
# 0.607

# %%
np.median(biased_flips)
# Out:
# 1.0

# %%
np.std(biased_flips, ddof=1)
# Out:
# 0.48866122190101174

# %%
norms = np.random.normal(loc=10, scale=1, size=1000)

# %%
sns.histplot(norms, stat="probability", kde=True)
# Out:
# <AxesSubplot:ylabel='Probability'>

# %%
from scipy.stats import binom_test

# %%
binom_test(x=8, n=10, p=0.5)
# Out:
# 0.10937500000000003

# %%
binom_test(x=800, n=1000, p=0.5)
# Out:
# 1.64499873557952e-85

# %%
binom_test(x=800, n=1000, p=0.79)
# Out:
# 0.4607894988486253

# %% [markdown]
# Even though our observed success rate was 80% we do not have enough evidence to conclude that the true success rate is different from 79%

# %%
sample1 = np.random.normal(loc=0, scale=1, size=1000)
sample2 = np.random.normal(loc=5, scale=2, size=1000)

# %%
sns.histplot(sample1, label='sample1', color='red', alpha=0.5)
sns.histplot(sample2, label='sample2', color='blue', alpha=0.5)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
from scipy.stats import ttest_ind

# %%
ttest_ind(sample1, sample2)
# Out:
# Ttest_indResult(statistic=-68.84038884315075, pvalue=0.0)

# %%
ttest_ind(sample1, sample2, equal_var=False)
# Out:
# Ttest_indResult(statistic=-68.84038884315076, pvalue=0.0)

# %%
sample1 = np.random.normal(loc=0, scale=1, size=10)
sample2 = np.random.normal(loc=2, scale=2, size=10)

sns.histplot(sample1, label='sample1', color='red', alpha=0.5)
sns.histplot(sample2, label='sample2', color='blue', alpha=0.5)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
ttest_ind(sample1, sample2, equal_var=False)
# Out:
# Ttest_indResult(statistic=0.03898674425391716, pvalue=0.9694037021222369)

# %%
sample1 = np.random.normal(loc=0, scale=1, size=1000)
sample2 = np.random.normal(loc=2, scale=2, size=1000)

sns.histplot(sample1, label='sample1', color='red', alpha=0.5)
sns.histplot(sample2, label='sample2', color='blue', alpha=0.5)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
ttest_ind(sample1, sample2, equal_var=False)
# Out:
# Ttest_indResult(statistic=-27.610372168523046, pvalue=1.3867933665277947e-135)
